# %% [markdown]
# # Machine Learning Tasks 2020

# %% [markdown]
# # 1. Square Root of 2

# %% [markdown]
# Task 1: is to use python to calculate the square root of two, without the aid of any maths libraries in python, to 100 decimal places.
#
# In order to get the square root of a number, we must first look at calculating a numbers square or multiplying itself by itself e.g. 3x3. The square of a number is followed by the number to the power of three and so on.
#
# Therefore if we look at the square root of a number, the number is the end goal - what number multiplied by itself gives us the resultant number. e.g. Square root of 25. We can look at it as X multiplied by X gets 25 - X^2 is 25. [2] When two numbers with exponents (numbers to the power of something) are multiplied we add the exponents to get the result shown below:

# %% [markdown]
# ![exp_plus.PNG](attachment:exp_plus.PNG)

# %% [markdown]
# <em> image taken from rapidtables [1]</em>

# %% [markdown]
# ![exp25.png](attachment:exp25.png)

# %% [markdown]
# Therefore in this example "n+m=1", "a = 25". "n" and "m" must both equal "0.5" as they must add up to one. We can now write a function X to the power of a half will give us the square meters of a number.

# %% [markdown]
# #### Use the basic maths to determine the Square Root of 2

# %% [markdown]
# The first attempt consisted of the below code. Where we declared a function and requested the output to 100 decimal places.

# %%
def sqr2(num):
    x = format(num**0.5, ',.100f') # [2] Code adapted from codegrepper
    return x

# %%
sqr2(2)
# Out:
# '1.4142135623730951454746218587388284504413604736328125000000000000000000000000000000000000000000000000'

# %% [markdown]
# The error shown above is down to how Python treats floating point numbers. Below are three examples of how decimal numbers are stored in Python, all three numbers are declared as floating points, with one decimal place.

# %%
print(format(1.5,',.50f'))
print(format(0.2,',.50f'))
print(format(0.1 + 0.1 + 0.1,',.50f'))
# Out:
# 1.50000000000000000000000000000000000000000000000000
# 0.20000000000000001110223024625156540423631668090820
# 0.30000000000000004440892098500626161694526672363281

# %% [markdown]
# The issue with the floating point number is that for each value Python would need a large storage area or a saved function to calculate the number. This is inefficient due to the large storage requirements. A workaround Python utilizes is that "the actual stored value is the nearest representable binary fraction."[3] This can be seen as a limitation when reviewing the above example.

# %% [markdown]
# The calculation therefore for the above listed <em>"sqr2"</em> has not stored the decimal in the correct fashion. The number is near to the end goal, however we have not achieved the 100 decimal places, correctly. We know this is incorrect as NASA [4] has calculated the square root of two to at least one million digits. The square root of two is an irrational number, which means it has infinite decimal places. TechTerms[5] refers to an irrational number as **"real number that cannot be expressed as a ratio of two integers"**. Therefore there is no pattern in the preceding decimal.

# %% [markdown]
# NASA: '1.4142135623730950488016887242096980785696718753769480731766797379907324784621070388503875343276415727'

# %% [markdown]
# #### Use the Newtons method to determine the Square Root of 2

# %% [markdown]
# An alternative means of calculating the Square root of 2 is to use Newtons method. A brief overview of Newtons method is to get an approximate value for the square root of a number and repeat the process unit and pre-determined acceptable tolerance is observed [7]. Below is a Python example of the Newton Method.

# %%
# The below code is adapted from 
# https://www.geeksforgeeks.org/find-root-of-a-number-using-newtons-method/

def squareRoot(num, tol) : 

    x = num  
  
    count = 0 
  
    while (1) : 
        count += 1 

        sqr_rt = 0.5 * (x + (num / x))  
  
        if (abs(sqr_rt - x) < tol) : 
            break 
  
        x = sqr_rt 
  
    return sqr_rt

# %%
format(squareRoot(2, 0.01),',.100f')
# Out:
# '1.4142156862745096645994635764509439468383789062500000000000000000000000000000000000000000000000000000'

# %% [markdown]
# The above floating point number still remains incorrect. An alternative method can be used. As know the calculation error appears at floating point numbers we can calculate without the decimal.
# NASA calculated the SqR of 2 to:
# '1.4142135623730950488016887242096980785696718753769480731766797379907324784621070388503875343276415727'
# If we remove the decimal the SqRoot of the number is
# A = '14142135623730950488016887242096980785696718753769480731766797379907324784621070388503875343276415727'
# Therefore A*A=A**2

# %%
A = 14142135623730950488016887242096980785696718753769480731766797379907324784621070388503875343276415727

# %%
asq = A*A
str(asq)
len(str(asq))
# Out:
# 201

# %%
a = 2*(10**200)
str(a)
len(str(a))
# Out:
# 201

# %%
Sqr2 = squareRoot(a,0.00001)
b = str(format((Sqr2),',.0f'))
d = b.replace(',', '')
print(d)
# Out:
# 14142135623730950271424125632818586983491648817919875481779003888601306842716543030228210043498528768

# %%
print('Basic Maths:      ' + sqr2(2)) 
print('Newtons Meathod:  ' + format(squareRoot(2, 0.000001),',.100f'))
print('Newtons *10**200: ' + d[0]+"."+d[1:])
print('NASA:             ' + '1.4142135623730950488016887242096980785696718753769480731766797379907324784621070388503875343276415727')
# Out:
# Basic Maths:      1.4142135623730951454746218587388284504413604736328125000000000000000000000000000000000000000000000000
# Newtons Meathod:  1.4142135623730949234300169337075203657150268554687500000000000000000000000000000000000000000000000000
# Newtons *10**200: 1.4142135623730950271424125632818586983491648817919875481779003888601306842716543030228210043498528768
# NASA:             1.4142135623730950488016887242096980785696718753769480731766797379907324784621070388503875343276415727

# %% [markdown]
# In conclusion the figures calculated do not match that calculated by NASA , the observed error may be down to a number of factors -  these may include tolerance errors or calculation errors.

# %% [markdown]
# 1. https://www.rapidtables.com/math/number/exponent/multiplying-exponents.html
# 2. https://www.codegrepper.com/code-examples/delphi/Limiting+floats+to+100+decimal+points+python
# 3. https://docs.python.org/3/tutorial/floatingpoint.html
# 4. https://apod.nasa.gov/htmltest/gifcity/sqrt2.1mil
# 5. https://techterms.com/definition/irrational_number
# 6. https://www.geeksforgeeks.org/find-root-of-a-number-using-newtons-method/
# 7. https://pages.mtu.edu/~shene/COURSES/cs201/NOTES/chap06/sqrt-1.html#:~:text=Newton's%20method%20suggests%20that%20a,the%20square%20root%20of%20b.

# %% [markdown]
# # 2. Chi-squared

# %% [markdown]
# Investopedia defines the Chi-squared test as <em>"measures how a model compares to actual observed data."[1]</em> This task was to Use scipy.stats to verify this value and calculate the associated p value. You should include a short note with references justifying your analysis in a markdown cell. Below is the table taken from the Wikipedia article mentioned in part of the task:

# %% [markdown]
# |              | A   | B   | C   | D   | total |
# | :----------- | --- | --- | --- | --- | ----- |
# | White collar | 90  | 60  | 104 | 95  | 349   |
# | Blue collar  | 30  | 50  | 51  | 20  | 151   |
# | No collar    | 30  | 40  | 45  | 35  | 150   |
# | Total        | 150 | 150 | 200 | 150 | 650   |

# %% [markdown]
# SciPy is a Python library used for maths, science and engineering. One of the functions contained within SciPy is "chi2_contingency". "This function computes the chi-square statistic and p-value for the hypothesis test of independence of the observed frequencies in the contingency table."[5]
#
# "The P-value is the probability of observing a sample statistic as extreme as the test statistic."[6]
#
# Alpha of the test is the degree of accuaracy we require or expect. An alpha of 0.1 is a tolerance of 10% accuracy.
#
# Degrees of Freedom are the number of variables in the equation. For the above example it is the number of rows and columns less one. A,B,C,D = 4 and White Collar, Blue Collar and No Collar 3 equal (4-1)(3-1) = 6. Therefore the number of degrees of freedom is six.

# %% [markdown]
# Using the above table we can calculate the various expected values for each location. Taking "White Collar A" as an example the expected results is calculated using (349/650)*150 = 80.538. All values are calculated in the same way. SciPy can complete the table as below:

# %% [markdown]
# The below formula demonstrates the Chi-Square test. The second formula: sum of all((observed sample - expected sample)Squared/expected sample) all resulting in chi squared.

# %% [markdown]
# ![Chi-square-test.jpg](attachment:Chi-square-test.jpg)

# %% [markdown]
# the above table was taken from : https://microbenotes.com/chi-square-test/

# %% [markdown]
# If we review the above table alongside our expected results,degrees of freedom of six with an alpho of 0.05. We can determine our critical our critical Chi Squared Value of 12.59
#
# ![Chi-Df6-Al0.05.PNG](attachment:Chi-Df6-Al0.05.PNG)

# %% [markdown]
# We can now use python to calculate the expected results.

# %%
# The following code was modified from the below link
# https://towardsdatascience.com/chi-squared-test-for-feature-selection-with-implementation-in-python-65b4ae7696db
# And the following code
from scipy.stats import chi2_contingency 
import numpy as np

# %%
# The table information converted to Lists
Desc = ["White","Blue","No"]
white_col = [90,60,104,95]
blue_col = [30,50,51,20]
no_col = [30,40,45,35]

data = np.array([white_col,blue_col,no_col])

# %%
stat, p_value, degree_of_freedom, expected = chi2_contingency(data)

# %% [markdown]
# |              | A   | B   | C   | D   | total |
# | :----------- | --- | --- | --- | --- | ----- |
# | White collar | 90  | 60  | 104 | 95  | 349   |
# | Blue collar  | 30  | 50  | 51  | 20  | 151   |
# | No collar    | 30  | 40  | 45  | 35  | 150   |
# | Total        | 150 | 150 | 200 | 150 | 650   |

# %%
print("===Expected Table===")
print(expected)
print("===Real Table===")
print(data)
# Out:
# ===Expected Table===
# [[ 80.53846154  80.53846154 107.38461538  80.53846154]
#  [ 34.84615385  34.84615385  46.46153846  34.84615385]
#  [ 34.61538462  34.61538462  46.15384615  34.61538462]]
# ===Real Table===
# [[ 90  60 104  95]
#  [ 30  50  51  20]
#  [ 30  40  45  35]]

# %% [markdown]
# We can now view the difference between the actual and the expected calculated by the "chi2_contingency"

# %%
for i in range(0,3):
    print(Desc[i] , " Collar")
    for y in range(0,4):
        print( "Actual:", data[i][y], "Expected:", round(expected[i][y],3), "Percentage Difference:", round((((expected[i][y])/(data[i][y])-1)*100),2),"%")
# Out:
# White  Collar
# Actual: 90 Expected: 80.538 Percentage Difference: -10.51 %
# Actual: 60 Expected: 80.538 Percentage Difference: 34.23 %
# Actual: 104 Expected: 107.385 Percentage Difference: 3.25 %
# Actual: 95 Expected: 80.538 Percentage Difference: -15.22 %
# Blue  Collar
# Actual: 30 Expected: 34.846 Percentage Difference: 16.15 %
# Actual: 50 Expected: 34.846 Percentage Difference: -30.31 %
# Actual: 51 Expected: 46.462 Percentage Difference: -8.9 %
# Actual: 20 Expected: 34.846 Percentage Difference: 74.23 %
# No  Collar
# Actual: 30 Expected: 34.615 Percentage Difference: 15.38 %
# Actual: 40 Expected: 34.615 Percentage Difference: -13.46 %
# Actual: 45 Expected: 46.154 Percentage Difference: 2.56 %
# Actual: 35 Expected: 34.615 Percentage Difference: -1.1 %

# %% [markdown]
# Additional information we re

# %%
print("The stat Value is " + str(stat))
print("The P Value is " + str(p_value))
print("The degree_of_freedom is " + str(degree_of_freedom))
# Out:
# The stat Value is 24.5712028585826
# The P Value is 0.0004098425861096696
# The degree_of_freedom is 6

# %% [markdown]
# From the above example the critical ChiSquare is 12.59 and the calculated Chi Sq is 24.571 this drasticly exceeds the value and therefore the null hypotheses is rejected. We can also review the P value, which is the "probability of observing a sample statistic as extreme as the test statistic."[6] In this case we observed a P Value of 0.00004098 which translates to a probability of a 0.04098425% chance.

# %% [markdown]
# 1. https://www.investopedia.com/terms/c/chi-square-statistic.asp
# 2. https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chisquare.html
# 3. https://towardsdatascience.com/running-chi-square-tests-in-python-with-die-roll-data-b9903817c51b
# 4. https://towardsdatascience.com/chi-squared-test-for-feature-selection-with-implementation-in-python-65b4ae7696db
# 5. https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi2_contingency.html?highlight=chi2_contingency#scipy.stats.chi2_contingency
# 6. https://stattrek.com/chi-square-test/goodness-of-fit.aspx#:~:text=The%20P%2Dvalue%20is%20the%20probability%20that%20a%20chi%2Dsquare,Interpret%20results.
# 7. https://www.youtube.com/watch?v=2QeDRsxSF9M

# %% [markdown]
# # 3. Standard Deviation

# %% [markdown]
# This element of the task is to use numpy to perform a simulation demonstrating that the STDEV.S calculation is a better estimate for the standard deviation of a population when performed on a sample.
#
# Standard deviation is the amount of difference, variance or spread in your population or sample of data from the mean of the group.
#
# "The STDEV.P function is used to calculate the standard deviation of the whole population. In fact, P in STDEVP stands for Population. If you have just a sample of data, then use STDEV.S function. The S in STDEVS stands for Sample." [1]

# %% [markdown]
# ![StDevP.PNG](attachment:StDevP.PNG)![StDevS.PNG](attachment:StDevS.PNG)

# %% [markdown]
# ![std_deviation_form.PNG](attachment:std_deviation_form.PNG)

# %% [markdown]
# The following YouTube [2] video confirms that - 𝜎 is the standard deviation of the of the entire population, while s is the standard deviation of the smaller sample of the population. Below is a example of the formulas used in excel to calculate the Standard Deviation.

# %%
import numpy as np

# %%
pop = [4,4,3,4,1,1,4,2,4,3,2,1,4,3,2,3,2,2,3,4,3,3,3,1,2,2,2,2,1,1]

# %% [markdown]
# In this example we have generated a sample array to calculate both the sample and the population.

# %% [markdown]
# ### StDEV.P

# %% [markdown]
# ![Exc_Std_P.PNG](attachment:Exc_Std_P.PNG)

# %%
def ST_DEV_P(n):
    mue = np.mean(n)
    sum = 0
    for i in n:
        sum += ((i-mue)**2)
    pop = len(n)
    stdev_p = np.sqrt(sum/pop)
    return stdev_p

# %%
ST_DEV_P(pop)
# Out:
# 1.0561986345169903

# %% [markdown]
# ### StDEV.S

# %% [markdown]
# ![Exc_Std_S.PNG](attachment:Exc_Std_S.PNG)

# %%
def ST_DEV_S(n):
    X_bar = np.mean(n)
    sum = 0
    for i in n:
        sum += ((i-X_bar)**2)
    sample = len(n)
    stdev_s = np.sqrt(sum/(sample-1))
    return stdev_s

# %%
ST_DEV_S(pop)
# Out:
# 1.0742546199601593

# %% [markdown]
# Both formulas are very similar - the standard deviation is calculated in the same way with one exception, the divider. To begin the mean of the array is calculated, for each value the mean is subtracted and the answer is then squared. The sum of each of these squares are totaled. The next step is where the calculation differs - for the population formula the total is divided by the overall population total while the sample formula uses the sample total less one. This subtraction provides a larger number for the standard deviation. Finally the square root of this number is then calculated to give the standard deviation.
#
# The population formula is the actual standard deviation of the array however when taking a sample of the data it is better to take a less sample size to increase the potential standard deviation. In the above example we used the entire array to demonstrate the output from both formulas.

# %% [markdown]
# 1. https://www.exceltip.com/statistical-formulas/how-to-use-excel-stdev-p-function.html#:~:text=Let's%20Explore.-,The%20STDEV.,sample%20of%20the%20entire%20population.
# 2. https://www.youtube.com/watch?v=wM4yjuTxQL4&t=300s

# %% [markdown]
# # 4. k Nearest Neighbours

# %% [markdown]
# Use scikit-learn to apply k-NN clustering to Fisher’s famous Iris data set. Explain in a Markdown cell how your code works and how accurate it might be, and then explain how your model could be used to make predictions of species of Iris.

# %% [markdown]
# Machine learning is seen as a dart art when in fact the principles are relatively straightforward. A sample of data, with reoccurring patterns is taken and a statistical test is carried out on it. We can then use this statistical model to determine the expected outcome of a datapoint.

# %% [markdown]
# k-Nearest Neighbours in one such model. kNN is based on the k average of nearest neighbours. When a training sample with a known measure and an expected outcome, the data can be plotted on an X Y graph, all the results are shown on plot as below. The statistical model uses the k average of the nearest neighbours to predict the desired result, below in green is desired resultant. If we assume a k value of three the green dot should be the combined average of what is shown in the solid circle - the green dot should be classified as a red triangle. If we increase the k value to 5, it is the average of everything inside the hatched area making it a blue square.
#
# Using the kNN we can predict the datapoint based on it closest or nearest measured samples.

# %% [markdown]
# ![knn3.png](attachment:knn3.png)
# the above image was taken from https://www.analyticsvidhya.com/blog/2018/03/introduction-k-neighbours-algorithm-clustering/

# %% [markdown]
# Firstly we import the libaries required.

# %%
from sklearn import datasets
from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# We can then import the CSV of the Iris dataset

# %%
file = 'iris.csv'
df = pd.read_csv(file)

# %% [markdown]
# We can now plot the data to graphs to gain a better insight. These below graphs illustrate all samples of dataset - plotting each column against one another. Each Species is coloured differently. It is very clear from the graphs that the Sepal length & width for the Setosa is a lot smaller than the other two species. For all other characteristics it is a lot more difficult to differentiate between the Virginica and Versica.

# %%
sns.pairplot(df, hue='species').add_legend().fig.suptitle('Plot Matrix')
plt.show()

# %% [markdown]
# The dataset it made up of 4 measurements and a plant species.

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# There are 150 sample data points 50 Setosa, Versicolor and Virginica. The dataframe is split into four seperate categories.
#
# The training data - the measure and the known target.
#
# The test data - the known measure and the predicted target.
#
# The below code splits the dataset into the above four categories at a 80-20 ratio - 80% into the training data and 20% into the test.

# %%
X = df.values[:,0:4]   
Y = df.values[:,4]

# %%
# X_train - Measurements to train the algorithm
# Y_train - Target to also train the algorithm
# X_validation - To test the measurements
# Y_validation - To test the target 
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=0.20, random_state=7)

# %% [markdown]
# We can now apply the function

# %%
knc = KNeighborsClassifier(n_neighbors=3).fit(X_train, Y_train)

# %% [markdown]
# Followed by the prediction

# %%
pred = knc.predict(X_validation)

# %% [markdown]
# The model can now review the predictions versus the actual data and conclude a 90% prediction rate.

# %%
metrics.accuracy_score(Y_validation,pred)
# Out:
# 0.9

# %% [markdown]
# Below is a visual representation of the prediction versus the true values. The model predicted the Setosa 7 out of 7 times. The model found it more difficult to predict the difference between the Versicolor and the Virginica. When reviewing the Iris data set it is clear that the Versicolor and the Virginica are more similar.

# %%
cm = confusion_matrix(Y_validation,pred)
cm_df = pd.DataFrame(cm,index = ['setosa','versicolor','virginica'], columns = ['setosa','versicolor','virginica'])
plt.figure(figsize=(15,5))
sns.heatmap(cm_df, annot=True)
plt.title( 'K-Nearest Neighbors' + ' \nAccuracy:{0:.2f}'.format(metrics.accuracy_score(Y_validation,pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# 1. https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm
# 2. https://github.com/EoghanDelaney/pands-project
# 3. https://towardsdatascience.com/machine-learning-basics-with-the-k-nearest-neighbors-algorithm-6a6e71d01761
# 4. https://www.javatpoint.com/k-nearest-neighbor-algorithm-for-machine-learning
